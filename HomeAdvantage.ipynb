# %% [markdown]
# # Analyse de l'avantage à domicile en Ligue 1
#
# Dans ce notebook, nous allons essayer de répondre à la question :
#
# > **Est-ce que jouer à domicile est un avantage ?**
#
# L’objectif est de construire la réponse **par étapes**, en réalisant une série de petits exercices avec `pandas`.
#
# On va notamment commencer par répondre à la question:
# > **Est-ce que jouer à domicile durant le COVID (saison 2020) est un avantage en Ligue 1 ?**
#
# puis on comparera par rapport à d'autres saisons en Ligue 1, puis en Liga.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# chargement de la saison 2020 Ligue 1

url_ligue1_2020 = "https://raw.githubusercontent.com/acherm/SEAI4Sport/refs/heads/main/season_matchs_Ligue_1_2020.csv"
data = pd.read_csv(url_ligue1_2020)

data.head()
# Out:
#    Unnamed: 0     id             datetime club_home   club_away  goal_home  \
# 0           0  13977  2020-08-21 17:00:00  Bordeaux      Nantes          0
# 1           1  13978  2020-08-22 15:00:00     Dijon      Angers          0
# 2           2  13979  2020-08-22 19:00:00     Lille      Rennes          1
# 3           3  13982  2020-08-23 11:00:00    Monaco       Reims          2
# 4           4  13980  2020-08-23 13:00:00   Lorient  Strasbourg          3
#
#    goal_away  result  result_away        xG       xGA  xPoints  xPointsAway
# 0          0       1            1  0.600075  0.187821   1.8613       0.6994
# 1          1       0            3  0.739709  2.022140   0.4217       2.3819
# 2          1       1            1  0.400974  1.295180   0.5357       2.1839
# 3          2       1            1  2.676220  1.832570   1.9379       0.8591
# 4          1       3            0  3.072140  0.326826   2.9185       0.0487

# %% [markdown]
# **Questions :**
#
# 1. En moyenne, combien de buts marque l’équipe à domicile (`goal_home`) ?
# 2. En moyenne, combien de buts marque l’équipe à l’extérieur (`goal_away`) ?
# 3. La moyenne de buts à domicile est-elle plus grande, plus petite ou similaire à celle à l’extérieur ?
# 4. À ce stade, que suggèrent ces chiffres sur l’avantage à domicile ?

# %% [markdown]
# **Questions :**
#
# 1. Combien de matchs sont gagnés par l’équipe à domicile ? Et par l’équipe à l’extérieur ?
# 2. Quel pourcentage de matchs est gagné à domicile ? À l’extérieur ? Terminé par un nul ?
# 3. Avec ces pourcentages, dirais-tu que jouer à domicile est un avantage (en termes de victoires) en 2020 ?

# %% [markdown]
# **Questions :**
#
# 1. En moyenne, combien de points une équipe gagne-t-elle lorsqu’elle joue à domicile ?
# 2. En moyenne, combien de points une équipe gagne-t-elle lorsqu’elle joue à l’extérieur ?
# 3. Lequel de ces deux nombres est le plus grand ?
# 4. Est-ce que cette différence te semble importante (en points par match) ?

# %% [markdown]
# **Questions :**
#
# 1. En moyenne, combien de points attendus (`xPoints`) pour les équipes à domicile ?
# 2. Et pour les équipes à l’extérieur (`xPointsAway`) ?
# 3. Est-ce cohérent avec ce que tu as observé pour les points réels (`result`) ?
# 4. Si ce n’est pas exactement pareil, comment expliquer ces petites différences ?

# %% [markdown]
# **Question :**
#
# À partir de tout ce que tu as calculé rédige une réponse complète à la question :
#
# > **Est-ce que jouer à domicile durant le COVID (saison 2020) est un avantage en Ligue 1 ?**
#
# Expliquer l’indicateur retenu pour mesurer l’avantage à domicile.
# Créer un graphique qui montre l’avantage (ou non) à domicile pendant la saison 2020
# Rédiger cette conclusion dans une cellule Markdown.

# %% [markdown]
# Rétitérez l'exercice:
#
# > Est-ce que jouer à domicile en période post-COVID (saison 2022) est un avantage en Ligue 1 ? (cf season_matchs_Ligue_1_2022.csv)
#
# > Est-ce que jouer à domicile en période post-COVID (saison 2023) est un avantage en Ligue 1 ? (cf season_matchs_Ligue_1_2023.csv)
#
# > Est-ce que jouer à domicile en période post-COVID (saison 2023) est un avantage dans le championnat d’Espagne? (cf season_matchs_La_liga_2023.csv)
#
# et écrire une réponse argumentée pour chaque question

# %%
url_ligue1_2022 = "https://raw.githubusercontent.com/acherm/SEAI4Sport/refs/heads/main/season_matchs_Ligue_1_2022.csv"
data_2022 = pd.read_csv(url_ligue1_2022)
